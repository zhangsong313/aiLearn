# %% [markdown]
# # 支持向量机

# %% [markdown]
# ## 原理

# %% [markdown]
# 什么样的分类边界是最好的？找到距离特征边界区域最近的一批点，距离这些点最远的分类边界就是最好的分类边界。

# %% [markdown]
# 假设分类边界为：

# %% [markdown]
# $W^TX + b = 0$

# %% [markdown]
# 其中,W为斜率向量，b为截距常数。

# %%
某个特征点到分类边界的距离为：

# %%
$distance(X, b, W)$

# %% [markdown]
# ## 软间隔

# %% [markdown]
# ## 低维不可分问题

# %% [markdown]
# ## 实战

# %% [markdown]
# ### 画出决策边界

# %%
# http://127.0.0.1:8888/lab/tree/aiLearn/day34_SVM/code/SVM/SVM%20-%201.ipynb

# %% [markdown]
# ### 不可分问题
